# %%
import pandas as pd

# %%
founders = pd.read_csv("/Users/Development/Desktop/pandasproject/founders.csv")

# %%
founders
# Out:
#   Founder's Name                               Pitch Line  Age  \
# 0  Alice Johnson         "Revolutionizing urban farming."   34
# 1      Bob Smith    "AI-driven solutions for healthcare."   45
# 2      Carol Lee   "Bringing clean energy to every home."   29
# 3   David Nguyen          "Enhancing e-commerce with AR."   38
# 4     Emma Brown    "Personalized learning for all ages."   31
# 5   Frank O'Hara       "Sustainable packaging solutions."   42
# 6   Grace Wilson  "Connecting freelancers with projects."   27
#
#                                Business Storytelling Capital (USD)  \
# 0  Alice grew up in a city with limited green spa...       250,000
# 1  After witnessing inefficiencies in hospital sy...     1,000,000
# 2  Carol's passion for renewable energy led her t...       500,000
# 3  David saw the potential of augmented reality t...       750,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
# ...

# %%
print(founders.head())
# Out:
#   Founder's Name                              Pitch Line  Age  \
# 0  Alice Johnson        "Revolutionizing urban farming."   34
# 1      Bob Smith   "AI-driven solutions for healthcare."   45
# 2      Carol Lee  "Bringing clean energy to every home."   29
# 3   David Nguyen         "Enhancing e-commerce with AR."   38
# 4     Emma Brown   "Personalized learning for all ages."   31
#
#                                Business Storytelling Capital (USD)  \
# 0  Alice grew up in a city with limited green spa...       250,000
# 1  After witnessing inefficiencies in hospital sy...     1,000,000
# 2  Carol's passion for renewable energy led her t...       500,000
# 3  David saw the potential of augmented reality t...       750,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
#
#   Marital Status
# 0         Single
# 1        Married
# 2         Single
# 3       Divorced
# 4        Married

# %%
print(founders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Founder's Name         7 non-null      object
#  1   Pitch Line             7 non-null      object
#  2   Age                    7 non-null      int64
#  3   Business Storytelling  7 non-null      object
#  4   Capital (USD)          7 non-null      object
#  5   Marital Status         7 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 468.0+ bytes
# None

# %%
filtered_founders = founders[founders["Age"] > 30]
filtered_founders
# Out:
#   Founder's Name                             Pitch Line  Age  \
# 0  Alice Johnson       "Revolutionizing urban farming."   34
# 1      Bob Smith  "AI-driven solutions for healthcare."   45
# 3   David Nguyen        "Enhancing e-commerce with AR."   38
# 4     Emma Brown  "Personalized learning for all ages."   31
# 5   Frank O'Hara     "Sustainable packaging solutions."   42
#
#                                Business Storytelling Capital (USD)  \
# 0  Alice grew up in a city with limited green spa...       250,000
# 1  After witnessing inefficiencies in hospital sy...     1,000,000
# 3  David saw the potential of augmented reality t...       750,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
# 5  Frank's concern for environmental waste led hi...       600,000
#
#   Marital Status
# 0         Single
# 1        Married
# 3       Divorced
# 4        Married
# 5         Single

# %%
founders["industery"] = founders["Pitch Line"] + founders["Capital (USD)"]
founders
# Out:
#   Founder's Name                               Pitch Line  Age  \
# 0  Alice Johnson         "Revolutionizing urban farming."   34
# 1      Bob Smith    "AI-driven solutions for healthcare."   45
# 2      Carol Lee   "Bringing clean energy to every home."   29
# 3   David Nguyen          "Enhancing e-commerce with AR."   38
# 4     Emma Brown    "Personalized learning for all ages."   31
# 5   Frank O'Hara       "Sustainable packaging solutions."   42
# 6   Grace Wilson  "Connecting freelancers with projects."   27
#
#                                Business Storytelling Capital (USD)  \
# 0  Alice grew up in a city with limited green spa...       250,000
# 1  After witnessing inefficiencies in hospital sy...     1,000,000
# 2  Carol's passion for renewable energy led her t...       500,000
# 3  David saw the potential of augmented reality t...       750,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
# ...

# %%
print(founders.describe())
# Out:
#              Age
# count   7.000000
# mean   35.142857
# std     6.768273
# min    27.000000
# 25%    30.000000
# 50%    34.000000
# 75%    40.000000
# max    45.000000

# %%
founders_sorted = founders.sort_values(by = "Age")
founders_sorted
# Out:
#   Founder's Name                               Pitch Line  Age  \
# 6   Grace Wilson  "Connecting freelancers with projects."   27
# 2      Carol Lee   "Bringing clean energy to every home."   29
# 4     Emma Brown    "Personalized learning for all ages."   31
# 0  Alice Johnson         "Revolutionizing urban farming."   34
# 3   David Nguyen          "Enhancing e-commerce with AR."   38
# 5   Frank O'Hara       "Sustainable packaging solutions."   42
# 1      Bob Smith    "AI-driven solutions for healthcare."   45
#
#                                Business Storytelling Capital (USD)  \
# 6  Grace created a platform that matches freelanc...       150,000
# 2  Carol's passion for renewable energy led her t...       500,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
# 0  Alice grew up in a city with limited green spa...       250,000
# 3  David saw the potential of augmented reality t...       750,000
# ...

# %%
married_founders = founders[founders["Marital Status"] == "Married" ]
married_founders
# Out:
#   Founder's Name                             Pitch Line  Age  \
# 1      Bob Smith  "AI-driven solutions for healthcare."   45
# 4     Emma Brown  "Personalized learning for all ages."   31
#
#                                Business Storytelling Capital (USD)  \
# 1  After witnessing inefficiencies in hospital sy...     1,000,000
# 4  Emma, a former teacher, launched an ed-tech pl...       300,000
#
#   Marital Status                                       industery
# 1        Married  "AI-driven solutions for healthcare."1,000,000
# 4        Married    "Personalized learning for all ages."300,000

# %%
founders.to_json('founders_data_modified.json', orient='records', lines=True)
fou

# %%
pip install --upgrade nbformat nbconvert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 269.5 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.9.2
#     Uninstalling nbformat-5.9.2:
#       Successfully uninstalled nbformat-5.9.2
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.10.0
#     Uninstalling nbconvert-7.10.0:
#       Successfully uninstalled nbconvert-7.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires nbformat==5.9.2, but you have nbformat 5.10.4 which is incompatible.
# ...
